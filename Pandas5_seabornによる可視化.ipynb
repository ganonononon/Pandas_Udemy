# %% [markdown]
# <a href="https://colab.research.google.com/github/ganonononon/Pandas_Udemy/blob/main/Pandas5_seaborn%E3%81%AB%E3%82%88%E3%82%8B%E5%8F%AF%E8%A6%96%E5%8C%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
file_path = '/content/drive/MyDrive/UdemyPandas/dataset/house_price_jp.csv'

# %%
df = pd.read_csv(file_path, sep=',')

# %%
df['Log10_price'] = df['price'].apply(lambda x: np.log10(x))

# %%
df['station_dis'] = pd.to_numeric(df['station_dis'], errors='coerce')
df['area'] = pd.to_numeric(df['area'], errors ='coerce')
df = df.dropna(subset=['station_dis','area'])

# %%
sns.scatterplot(data=df, x='building_year', y='Log10_price')
# Out:
# <Axes: xlabel='building_year', ylabel='Log10_price'>

# %%
# !pip install japanize_matplotlib
# Out:
# Collecting japanize_matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 52.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from japanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.17.0)
# Building wheels for collected packages: japanize_matplotlib
#   Building wheel for japanize_matplotlib (setup.py) ... done
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=e8737b4df3bedc3d0e6e0064b64345f3976f521b98fcd2919fbc189cb88772a9
#   Stored in directory: /root/.cache/pip/wheels/da/a1/71/b8faeb93276fed10edffcca20746f1ef6f8d9e071eee8425fc
# Successfully built japanize_matplotlib
# Installing collected packages: japanize_matplotlib
# Successfully installed japanize_matplotlib-1.1.3

# %%
import japanize_matplotlib

# %%
df['room'] .unique()
# Out:
# array(['３ＬＤＫ', '２ＬＤＫ', '１Ｒ', '１ＤＫ', nan, '１ＬＤＫ', '２ＤＫ', '４ＬＤＫ', '１Ｋ',
#        '３ＬＤＫ＋Ｓ', '２ＬＤＫ＋Ｓ', '５ＬＤＫ', '１ＬＤＫ＋Ｓ', '３ＤＫ', '４ＤＫ', 'オープンフロア',
#        '２Ｋ', '２ＤＫ＋Ｓ', '１ＤＫ＋Ｓ', '３Ｋ', '４ＬＤＫ＋Ｓ', '４Ｋ', '５ＤＫ'], dtype=object)

# %%
target_room = ['３ＬＤＫ', '２ＬＤＫ', '１Ｒ']
target_df = df.query('room in @target_room')
sns.scatterplot(data=target_df, x='building_year', y='Log10_price', hue='room', alpha=0.5)
# Out:
# <Axes: xlabel='building_year', ylabel='Log10_price'>

# %% [markdown]
# joinplot

# %%
# !pip install --upgrade seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
sns.jointplot(data=target_df, x='building_year', y='Log10_price', kind='hex')

# %%
target_df.select_dtypes(['float64', 'int64']).columns
# Out:
# Index(['index', 'building_year', 'station_dis', 'price', 'price_per_tsubo',
#        'area', 'frontage', 'BCR', 'FAR', 'Lof10_price', 'Log10_price'],
#       dtype='object')

# %%
col_names = ['building_year', 'station_dis',
             'area', 'frontage', 'BCR', 'FAR', 'Log10_price'] + ['room']

# %% [markdown]
# 重い

# %%
sns.pairplot(data=target_df[col_names], hue='room')

# %% [markdown]
# histplot boxplot violinplot

# %%
sns.histplot(data=target_df, x='Log10_price', hue='room', stat='density')
# Out:
# <Axes: xlabel='Log10_price', ylabel='Density'>

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(18, 8))
fig = sns.boxplot(data=df, x='prefecture', y='Log10_price')
fig = plt.xticks(rotation=90)

# %%
fig = plt.figure(figsize=(18, 8))
fig = sns.violinplot(data=df, x='prefecture', y='Log10_price')
fig = plt.xticks(rotation=90)

# %% [markdown]
# ヒートマップ

# %%
df
# Out:
#        index       type land_type prefecture    city city2 station_name  \
# 0          1   中古マンション等       NaN        北海道  札幌市中央区   大通西        西１１丁目
# 1          2   中古マンション等       NaN        北海道  札幌市中央区   大通西        西１１丁目
# 2          3   中古マンション等       NaN        北海道  札幌市中央区   大通西        西１８丁目
# 3          4   中古マンション等       NaN        北海道  札幌市中央区   大通西        西１８丁目
# 4          5   中古マンション等       NaN        北海道  札幌市中央区   大通西        西１８丁目
# ...      ...        ...       ...        ...     ...   ...          ...
# 19851  36272   中古マンション等       NaN        沖縄県     那覇市    牧志          美栄橋
# 19852  36274  宅地(土地と建物)       住宅地        沖縄県     那覇市   字松川    市立病院前(沖縄)
# 19853  36275   中古マンション等       NaN        沖縄県     那覇市    銘苅           古島
# 19854  36276   中古マンション等       NaN        沖縄県     那覇市    寄宮           安里
# 19895  36378  宅地(土地と建物)       商業地        沖縄県  中頭郡西原町   字翁長        てだこ浦西
#
#        building_year  station_dis      price  ...    area land_shape  \
# 0               2016          1.0   37000000  ...    75.0        NaN
# 1               2012          3.0   57000000  ...    75.0        NaN
# 2               1981          3.0   17000000  ...    50.0        NaN
# 3               1977          0.0    3200000  ...    20.0        NaN
# 4               1989          2.0   17000000  ...    50.0        NaN
# ...              ...          ...        ...  ...     ...        ...
# 19851           2002          6.0   38000000  ...    75.0        NaN
# 19852           2022          9.0   44000000  ...   120.0      ほぼ長方形
# 19853           2019          3.0   58000000  ...    80.0        NaN
# 19854           1990         15.0   15000000  ...    50.0        NaN
# 19895           1986         10.0  230000000  ...  1100.0       ほぼ台形
#
#        frontage gross_floor_area  building_type     city_plan   BCR    FAR  \
# 0           NaN              NaN             ＲＣ          商業地域  80.0  600.0
# 1           NaN              NaN             ＲＣ          商業地域  80.0  600.0
# 2           NaN              NaN             ＲＣ          商業地域  80.0  400.0
# 3           NaN              NaN            ＳＲＣ          商業地域  80.0  400.0
# 4           NaN              NaN            ＳＲＣ          商業地域  80.0  400.0
# ...         ...              ...            ...           ...   ...    ...
# 19851       NaN              NaN             ＲＣ          商業地域  80.0  400.0
# 19852       9.0               95             木造   第１種低層住居専用地域  50.0  100.0
# 19853       NaN              NaN             ＲＣ       第２種住居地域  60.0  200.0
# 19854       NaN              NaN             ＲＣ  第１種中高層住居専用地域  60.0  200.0
# 19895      26.0          2000㎡以上             ＲＣ       第１種住居地域  60.0  200.0
#
#        Lof10_price  Log10_price
# 0         7.568202     7.568202
# 1         7.755875     7.755875
# 2         7.230449     7.230449
# 3         6.505150     6.505150
# 4         7.230449     7.230449
# ...            ...          ...
# 19851     7.579784     7.579784
# 19852     7.643453     7.643453
# 19853     7.763428     7.763428
# 19854     7.176091     7.176091
# 19895     8.361728     8.361728
#
# [15663 rows x 22 columns]

# %%
df['building_type'].unique()
# Out:
# array(['ＲＣ', 'ＳＲＣ', '鉄骨造', '木造', nan, '軽量鉄骨造', 'ＲＣ、木造', 'ブロック造',
#        '木造、ブロック造', '鉄骨造、軽量鉄骨造', 'ＳＲＣ、ＲＣ', '鉄骨造、木造', 'ＲＣ、木造、軽量鉄骨造',
#        '木造、軽量鉄骨造', 'ＳＲＣ、鉄骨造', 'ＲＣ、鉄骨造', 'ＲＣ、鉄骨造、木造'], dtype=object)

# %%
target_building_type = ['ＲＣ', 'ＳＲＣ', '鉄骨造', '木造']
query = 'building_type in @target_building_type'
my_pivot = pd.pivot_table(df.query(query), index='building_type',
                         columns='city_plan', values='index', aggfunc='count')
my_pivot
# Out:
# city_plan        商業地域   工業地域  工業専用地域  市街化区域及び市街化調整区域外の都市計画区域  市街化調整区域  準住居地域  \
# building_type
# 木造              138.0   68.0     1.0                   269.0    286.0   56.0
# 鉄骨造             127.0   36.0     8.0                    24.0     24.0   13.0
# ＲＣ             1442.0  147.0     NaN                     5.0     16.0  123.0
# ＳＲＣ            1035.0   26.0     NaN                     NaN     11.0   20.0
#
# city_plan      準工業地域  準都市計画区域  第１種中高層住居専用地域  第１種低層住居専用地域  第１種住居地域  \
# building_type
# 木造             366.0      6.0        1046.0       1677.0   1542.0
# 鉄骨造             83.0      1.0          67.0         20.0    128.0
# ＲＣ             665.0      NaN         746.0        220.0    853.0
# ＳＲＣ            216.0      NaN         158.0          5.0    211.0
#
# city_plan      第２種中高層住居専用地域  第２種低層住居専用地域  第２種住居地域  近隣商業地域  都市計画区域外
# building_type
# 木造                    431.0         54.0    216.0   219.0     82.0
# 鉄骨造                    38.0          3.0     45.0   100.0     10.0
# ＲＣ                    240.0         17.0    287.0   635.0      3.0
# ＳＲＣ                    50.0          NaN     57.0   192.0      NaN

# %%
fig = plt.figure(figsize=(20, 8))
fig = sns.heatmap(my_pivot, annot=True, cmap='RdBu_r')

# %% [markdown]
# facetGrid

# %%
query = 'building_type in ["ＲＣ", "ＳＲＣ", "鉄骨造", "木造"]'
fig = sns.scatterplot(data=df.query(query), x='building_year',
                      y='Log10_price', hue='building_type', alpha=0.4)

# %%
g = sns.FacetGrid(df.query(query), col='building_type')
g.map(sns.scatterplot, 'building_year', 'Log10_price')
