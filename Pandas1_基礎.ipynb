# %% [markdown]
# <a href="https://colab.research.google.com/github/ganonononon/Pandas_Udemy/blob/main/Pandas1_%E5%9F%BA%E7%A4%8E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ライブラリのインポート

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = px.data.gapminder()
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %% [markdown]
# データの抽出

# %%
df['lifeExp']
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: lifeExp, Length: 1704, dtype: float64

# %% [markdown]
# popurationの列を全て抽出

# %%
df.loc[:, 'pop']
# Out:
# 0        8425333
# 1        9240934
# 2       10267083
# 3       11537966
# 4       13079460
#           ...
# 1699     9216418
# 1700    10704340
# 1701    11404948
# 1702    11926563
# 1703    12311143
# Name: pop, Length: 1704, dtype: int64

# %% [markdown]
# リストにしてみる

# %%
df.loc[:, ['country', 'pop']]
# Out:
#           country       pop
# 0     Afghanistan   8425333
# 1     Afghanistan   9240934
# 2     Afghanistan  10267083
# 3     Afghanistan  11537966
# 4     Afghanistan  13079460
# ...           ...       ...
# 1699     Zimbabwe   9216418
# 1700     Zimbabwe  10704340
# 1701     Zimbabwe  11404948
# 1702     Zimbabwe  11926563
# 1703     Zimbabwe  12311143
#
# [1704 rows x 2 columns]

# %%
df.loc[0:10, ['country', 'pop']]
# Out:
#         country       pop
# 0   Afghanistan   8425333
# 1   Afghanistan   9240934
# 2   Afghanistan  10267083
# 3   Afghanistan  11537966
# 4   Afghanistan  13079460
# 5   Afghanistan  14880372
# 6   Afghanistan  12881816
# 7   Afghanistan  13867957
# 8   Afghanistan  16317921
# 9   Afghanistan  22227415
# 10  Afghanistan  25268405

# %% [markdown]
# 指定の列のデータを取得できる

# %%
df.iloc[:, 4]
# Out:
# 0        8425333
# 1        9240934
# 2       10267083
# 3       11537966
# 4       13079460
#           ...
# 1699     9216418
# 1700    10704340
# 1701    11404948
# 1702    11926563
# 1703    12311143
# Name: pop, Length: 1704, dtype: int64

# %% [markdown]
# リスト

# %%
df.iloc[:, [3,4,5]]
# Out:
#       lifeExp       pop   gdpPercap
# 0      28.801   8425333  779.445314
# 1      30.332   9240934  820.853030
# 2      31.997  10267083  853.100710
# 3      34.020  11537966  836.197138
# 4      36.088  13079460  739.981106
# ...       ...       ...         ...
# 1699   62.351   9216418  706.157306
# 1700   60.377  10704340  693.420786
# 1701   46.809  11404948  792.449960
# 1702   39.989  11926563  672.038623
# 1703   43.487  12311143  469.709298
#
# [1704 rows x 3 columns]

# %% [markdown]
# ３から６までのデータの取得

# %%
df.iloc[:, 3:6]
# Out:
#       lifeExp       pop   gdpPercap
# 0      28.801   8425333  779.445314
# 1      30.332   9240934  820.853030
# 2      31.997  10267083  853.100710
# 3      34.020  11537966  836.197138
# 4      36.088  13079460  739.981106
# ...       ...       ...         ...
# 1699   62.351   9216418  706.157306
# 1700   60.377  10704340  693.420786
# 1701   46.809  11404948  792.449960
# 1702   39.989  11926563  672.038623
# 1703   43.487  12311143  469.709298
#
# [1704 rows x 3 columns]

# %% [markdown]
# T→カラムとインデックスを入れ替える天地

# %%
df.T
# Out:
#                   0            1            2            3            4     \
# country    Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# continent         Asia         Asia         Asia         Asia         Asia
# year              1952         1957         1962         1967         1972
# lifeExp         28.801       30.332       31.997        34.02       36.088
# pop            8425333      9240934     10267083     11537966     13079460
# gdpPercap   779.445314    820.85303    853.10071   836.197138   739.981106
# iso_alpha          AFG          AFG          AFG          AFG          AFG
# iso_num              4            4            4            4            4
#
#                   5            6            7            8            9     \
# country    Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# continent         Asia         Asia         Asia         Asia         Asia
# ...

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %% [markdown]
# 先頭から3行取ってくる

# %%
df.head(3)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4

# %% [markdown]
# 末尾から5行

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716

# %% [markdown]
# データの数

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %% [markdown]
# カラムの種類

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap',
#        'iso_alpha', 'iso_num'],
#       dtype='object')

# %% [markdown]
# 縦と横の数

# %%
df.shape
# Out:
# (1704, 8)

# %% [markdown]
# 100万行あってサンプリングしたい

# %%
df.sample(100)
# Out:
#          country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 50     Argentina  Americas  1962   65.142   21283783   7133.166023       ARG
# 1059     Namibia    Africa  1967   51.159     706640   3793.694753       NAM
# 13       Albania    Europe  1957   59.280    1476505   1942.284244       ALB
# 696        India      Asia  1952   37.373  372000000    546.565749       IND
# 751      Ireland    Europe  1987   74.360    3539900  13872.866520       IRL
# ...          ...       ...   ...      ...        ...           ...       ...
# 1169    Pakistan      Asia  1977   54.043   78152686   1175.921193       PAK
# 1038  Mozambique    Africa  1982   42.795   12587223    462.211415       MOZ
# 1161        Oman      Asia  1997   72.499    2283635  19702.055810       OMN
# 86       Bahrain      Asia  1962   56.923     171863  12753.275140       BHR
# 423     Djibouti    Africa  1967   42.074     127617   3020.050513       DJI
#
#       iso_num
# 50         32
# ...

# %% [markdown]
# データの生成・消去

# %%
df['flag'] = 1

# %%
df.head(2)
# Out:
#        country continent  year  lifeExp      pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332  9240934  820.853030       AFG
#
#    iso_num  flag
# 0        4     1
# 1        4     1

# %%
df.loc[1704, :] = 1

# %%
df.tail(5)
# Out:
#        country continent    year  lifeExp         pop   gdpPercap iso_alpha  \
# 1700  Zimbabwe    Africa  1992.0   60.377  10704340.0  693.420786       ZWE
# 1701  Zimbabwe    Africa  1997.0   46.809  11404948.0  792.449960       ZWE
# 1702  Zimbabwe    Africa  2002.0   39.989  11926563.0  672.038623       ZWE
# 1703  Zimbabwe    Africa  2007.0   43.487  12311143.0  469.709298       ZWE
# 1704         1         1     1.0    1.000         1.0    1.000000         1
#
#       iso_num  flag
# 1700    716.0   1.0
# 1701    716.0   1.0
# 1702    716.0   1.0
# 1703    716.0   1.0
# 1704      1.0   1.0

# %% [markdown]
# 消去

# %%
df.drop(1704)
# Out:
#           country continent    year  lifeExp         pop   gdpPercap  \
# 0     Afghanistan      Asia  1952.0   28.801   8425333.0  779.445314
# 1     Afghanistan      Asia  1957.0   30.332   9240934.0  820.853030
# 2     Afghanistan      Asia  1962.0   31.997  10267083.0  853.100710
# 3     Afghanistan      Asia  1967.0   34.020  11537966.0  836.197138
# 4     Afghanistan      Asia  1972.0   36.088  13079460.0  739.981106
# ...           ...       ...     ...      ...         ...         ...
# 1699     Zimbabwe    Africa  1987.0   62.351   9216418.0  706.157306
# 1700     Zimbabwe    Africa  1992.0   60.377  10704340.0  693.420786
# 1701     Zimbabwe    Africa  1997.0   46.809  11404948.0  792.449960
# 1702     Zimbabwe    Africa  2002.0   39.989  11926563.0  672.038623
# 1703     Zimbabwe    Africa  2007.0   43.487  12311143.0  469.709298
#
#      iso_alpha  iso_num  flag
# 0          AFG      4.0   1.0
# 1          AFG      4.0   1.0
# 2          AFG      4.0   1.0
# ...

# %% [markdown]
# dropしたものを保持

# %%
df = df.drop(1704)

# %%
df
# Out:
#           country continent    year  lifeExp         pop   gdpPercap  \
# 0     Afghanistan      Asia  1952.0   28.801   8425333.0  779.445314
# 1     Afghanistan      Asia  1957.0   30.332   9240934.0  820.853030
# 2     Afghanistan      Asia  1962.0   31.997  10267083.0  853.100710
# 3     Afghanistan      Asia  1967.0   34.020  11537966.0  836.197138
# 4     Afghanistan      Asia  1972.0   36.088  13079460.0  739.981106
# ...           ...       ...     ...      ...         ...         ...
# 1699     Zimbabwe    Africa  1987.0   62.351   9216418.0  706.157306
# 1700     Zimbabwe    Africa  1992.0   60.377  10704340.0  693.420786
# 1701     Zimbabwe    Africa  1997.0   46.809  11404948.0  792.449960
# 1702     Zimbabwe    Africa  2002.0   39.989  11926563.0  672.038623
# 1703     Zimbabwe    Africa  2007.0   43.487  12311143.0  469.709298
#
#      iso_alpha  iso_num  flag
# 0          AFG      4.0   1.0
# 1          AFG      4.0   1.0
# 2          AFG      4.0   1.0
# ...

# %%
df.drop('flag', axis=1, inplace=True)

# %%
df
# Out:
#           country continent    year  lifeExp         pop   gdpPercap  \
# 0     Afghanistan      Asia  1952.0   28.801   8425333.0  779.445314
# 1     Afghanistan      Asia  1957.0   30.332   9240934.0  820.853030
# 2     Afghanistan      Asia  1962.0   31.997  10267083.0  853.100710
# 3     Afghanistan      Asia  1967.0   34.020  11537966.0  836.197138
# 4     Afghanistan      Asia  1972.0   36.088  13079460.0  739.981106
# ...           ...       ...     ...      ...         ...         ...
# 1699     Zimbabwe    Africa  1987.0   62.351   9216418.0  706.157306
# 1700     Zimbabwe    Africa  1992.0   60.377  10704340.0  693.420786
# 1701     Zimbabwe    Africa  1997.0   46.809  11404948.0  792.449960
# 1702     Zimbabwe    Africa  2002.0   39.989  11926563.0  672.038623
# 1703     Zimbabwe    Africa  2007.0   43.487  12311143.0  469.709298
#
#      iso_alpha  iso_num
# 0          AFG      4.0
# 1          AFG      4.0
# 2          AFG      4.0
# 3          AFG      4.0
# ...

# %% [markdown]
# データの生成

# %%
df2 = df.copy()

# %%
df2
# Out:
#           country continent    year  lifeExp         pop   gdpPercap  \
# 0     Afghanistan      Asia  1952.0   28.801   8425333.0  779.445314
# 1     Afghanistan      Asia  1957.0   30.332   9240934.0  820.853030
# 2     Afghanistan      Asia  1962.0   31.997  10267083.0  853.100710
# 3     Afghanistan      Asia  1967.0   34.020  11537966.0  836.197138
# 4     Afghanistan      Asia  1972.0   36.088  13079460.0  739.981106
# ...           ...       ...     ...      ...         ...         ...
# 1699     Zimbabwe    Africa  1987.0   62.351   9216418.0  706.157306
# 1700     Zimbabwe    Africa  1992.0   60.377  10704340.0  693.420786
# 1701     Zimbabwe    Africa  1997.0   46.809  11404948.0  792.449960
# 1702     Zimbabwe    Africa  2002.0   39.989  11926563.0  672.038623
# 1703     Zimbabwe    Africa  2007.0   43.487  12311143.0  469.709298
#
#      iso_alpha  iso_num
# 0          AFG      4.0
# 1          AFG      4.0
# 2          AFG      4.0
# 3          AFG      4.0
# ...

# %% [markdown]
# データ型

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year         float64
# lifeExp      float64
# pop          float64
# gdpPercap    float64
# iso_alpha     object
# iso_num      float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   float64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 106.6+ KB

# %% [markdown]
# データ型の変換

# %%
df['year'] = df['year'].astype(str)

# %%
df['year'] = df['year'].astype(float)

# %% [markdown]
# 変換に便利なメソッド

# %%
df.loc[1704, 'year'] = 'abc'
# Out:
# <ipython-input-34-480a9da15e25>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'abc' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[1704, 'year'] = 'abc'

# %%
df
# Out:
#           country continent    year  lifeExp         pop   gdpPercap  \
# 0     Afghanistan      Asia  1952.0   28.801   8425333.0  779.445314
# 1     Afghanistan      Asia  1957.0   30.332   9240934.0  820.853030
# 2     Afghanistan      Asia  1962.0   31.997  10267083.0  853.100710
# 3     Afghanistan      Asia  1967.0   34.020  11537966.0  836.197138
# 4     Afghanistan      Asia  1972.0   36.088  13079460.0  739.981106
# ...           ...       ...     ...      ...         ...         ...
# 1700     Zimbabwe    Africa  1992.0   60.377  10704340.0  693.420786
# 1701     Zimbabwe    Africa  1997.0   46.809  11404948.0  792.449960
# 1702     Zimbabwe    Africa  2002.0   39.989  11926563.0  672.038623
# 1703     Zimbabwe    Africa  2007.0   43.487  12311143.0  469.709298
# 1704          NaN       NaN     abc      NaN         NaN         NaN
#
#      iso_alpha  iso_num
# 0          AFG      4.0
# 1          AFG      4.0
# 2          AFG      4.0
# 3          AFG      4.0
# ...

# %%
df['year'] = pd.to_numeric(df['year'], errors='coerce')

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year         float64
# lifeExp      float64
# pop          float64
# gdpPercap    float64
# iso_alpha     object
# iso_num      float64
# dtype: object

# %% [markdown]
# 特定のデータ型だけを抽出
# オブジェクト型だけを抽出したりできる

# %%
df.select_dtypes(include='object')
# Out:
#           country continent iso_alpha
# 0     Afghanistan      Asia       AFG
# 1     Afghanistan      Asia       AFG
# 2     Afghanistan      Asia       AFG
# 3     Afghanistan      Asia       AFG
# 4     Afghanistan      Asia       AFG
# ...           ...       ...       ...
# 1700     Zimbabwe    Africa       ZWE
# 1701     Zimbabwe    Africa       ZWE
# 1702     Zimbabwe    Africa       ZWE
# 1703     Zimbabwe    Africa       ZWE
# 1704          NaN       NaN       NaN
#
# [1705 rows x 3 columns]

# %% [markdown]
# カラムの一覧を取得できる

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['country', 'continent', 'iso_alpha'], dtype='object')

# %% [markdown]
# 数値型のみ、統計値を出せる

# %%
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap      iso_num
# count  1704.00000  1704.000000  1.704000e+03    1704.000000  1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081   425.880282
# std      17.26533    12.917107  1.061579e+08    9857.454543   248.305709
# min    1952.00000    23.599000  6.001100e+04     241.165876     4.000000
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309   208.000000
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989   410.000000
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346   638.000000
# max    2007.00000    82.603000  1.318683e+09  113523.132900   894.000000

# %% [markdown]
# データのカウント・並び替え

# %%
df
# Out:
#           country continent    year  lifeExp         pop   gdpPercap  \
# 0     Afghanistan      Asia  1952.0   28.801   8425333.0  779.445314
# 1     Afghanistan      Asia  1957.0   30.332   9240934.0  820.853030
# 2     Afghanistan      Asia  1962.0   31.997  10267083.0  853.100710
# 3     Afghanistan      Asia  1967.0   34.020  11537966.0  836.197138
# 4     Afghanistan      Asia  1972.0   36.088  13079460.0  739.981106
# ...           ...       ...     ...      ...         ...         ...
# 1700     Zimbabwe    Africa  1992.0   60.377  10704340.0  693.420786
# 1701     Zimbabwe    Africa  1997.0   46.809  11404948.0  792.449960
# 1702     Zimbabwe    Africa  2002.0   39.989  11926563.0  672.038623
# 1703     Zimbabwe    Africa  2007.0   43.487  12311143.0  469.709298
# 1704          NaN       NaN     NaN      NaN         NaN         NaN
#
#      iso_alpha  iso_num
# 0          AFG      4.0
# 1          AFG      4.0
# 2          AFG      4.0
# 3          AFG      4.0
# ...

# %%
df.drop(1704, inplace=True)

# %% [markdown]
# 固有の要素の数を知る
# .nunipue

# %%
df['country'].nunique()
# Out:
# 142

# %%
df['continent'].value_counts()
# Out:
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64

# %% [markdown]
# 昇順

# %%
df['continent'].value_counts(ascending=True)
# Out:
# continent
# Oceania      24
# Americas    300
# Europe      360
# Asia        396
# Africa      624
# Name: count, dtype: int64

# %% [markdown]
# 並び替え

# %%
df.sort_values(by='year')
# Out:
#                  country continent    year  lifeExp          pop  \
# 0            Afghanistan      Asia  1952.0   28.801    8425333.0
# 528               France    Europe  1952.0   67.410   42459667.0
# 540                Gabon    Africa  1952.0   37.003     420702.0
# 1656  West Bank and Gaza      Asia  1952.0   43.160    1030585.0
# 552               Gambia    Africa  1952.0   30.000     284320.0
# ...                  ...       ...     ...      ...          ...
# 1127               Niger    Africa  2007.0   56.867   12894865.0
# 1139             Nigeria    Africa  2007.0   46.859  135031164.0
# 1151              Norway    Europe  2007.0   80.196    4627926.0
# 1175            Pakistan      Asia  2007.0   65.483  169270617.0
# 1703            Zimbabwe    Africa  2007.0   43.487   12311143.0
#
#          gdpPercap iso_alpha  iso_num
# 0       779.445314       AFG      4.0
# 528    7029.809327       FRA    250.0
# 540    4293.476475       GAB    266.0
# ...

# %% [markdown]
# 降順

# %%
df.sort_values(by='year', ascending=False)
# Out:
#                 country continent    year  lifeExp         pop      gdpPercap  \
# 1703           Zimbabwe    Africa  2007.0   43.487  12311143.0     469.709298
# 491   Equatorial Guinea    Africa  2007.0   51.579    551201.0   12154.089750
# 515            Ethiopia    Africa  2007.0   52.947  76511887.0     690.805576
# 527             Finland    Europe  2007.0   79.313   5238460.0   33207.084400
# 539              France    Europe  2007.0   80.657  61083916.0   30470.016700
# ...                 ...       ...     ...      ...         ...            ...
# 1116              Niger    Africa  1952.0   37.444   3379468.0     761.879376
# 1128            Nigeria    Africa  1952.0   36.324  33119096.0    1077.281856
# 1140             Norway    Europe  1952.0   72.670   3327728.0   10095.421720
# 1152               Oman      Asia  1952.0   37.578    507833.0    1828.230307
# 852              Kuwait      Asia  1952.0   55.565    160000.0  108382.352900
#
#      iso_alpha  iso_num
# ...

# %%
df.sort_values(by=['year', 'lifeExp'],ascending=False)
# Out:
#                country continent    year  lifeExp          pop     gdpPercap  \
# 803              Japan      Asia  2007.0   82.603  127467972.0  31656.068060
# 671   Hong Kong, China      Asia  2007.0   82.208    6980412.0  39724.978670
# 695            Iceland    Europe  2007.0   81.757     301931.0  36180.789190
# 1487       Switzerland    Europe  2007.0   81.701    7554661.0  37506.419070
# 71           Australia   Oceania  2007.0   81.235   20434176.0  34435.367440
# ...                ...       ...     ...      ...          ...           ...
# 1032        Mozambique    Africa  1952.0   31.286    6446316.0    468.526038
# 1344      Sierra Leone    Africa  1952.0   30.331    2143249.0    879.787736
# 36              Angola    Africa  1952.0   30.015    4232095.0   3520.610273
# 552             Gambia    Africa  1952.0   30.000     284320.0    485.230659
# 0          Afghanistan      Asia  1952.0   28.801    8425333.0    779.445314
#
#      iso_alpha  iso_num
# ...

# %% [markdown]
# 演算・統計量の計算

# %%
df
# Out:
#           country continent    year  lifeExp         pop   gdpPercap  \
# 0     Afghanistan      Asia  1952.0   28.801   8425333.0  779.445314
# 1     Afghanistan      Asia  1957.0   30.332   9240934.0  820.853030
# 2     Afghanistan      Asia  1962.0   31.997  10267083.0  853.100710
# 3     Afghanistan      Asia  1967.0   34.020  11537966.0  836.197138
# 4     Afghanistan      Asia  1972.0   36.088  13079460.0  739.981106
# ...           ...       ...     ...      ...         ...         ...
# 1699     Zimbabwe    Africa  1987.0   62.351   9216418.0  706.157306
# 1700     Zimbabwe    Africa  1992.0   60.377  10704340.0  693.420786
# 1701     Zimbabwe    Africa  1997.0   46.809  11404948.0  792.449960
# 1702     Zimbabwe    Africa  2002.0   39.989  11926563.0  672.038623
# 1703     Zimbabwe    Africa  2007.0   43.487  12311143.0  469.709298
#
#      iso_alpha  iso_num
# 0          AFG      4.0
# 1          AFG      4.0
# 2          AFG      4.0
# 3          AFG      4.0
# ...

# %%
df['lifeExp'] + 3
# Out:
# 0       31.801
# 1       33.332
# 2       34.997
# 3       37.020
# 4       39.088
#          ...
# 1699    65.351
# 1700    63.377
# 1701    49.809
# 1702    42.989
# 1703    46.487
# Name: lifeExp, Length: 1704, dtype: float64

# %%
2 * df['lifeExp']
# Out:
# 0        57.602
# 1        60.664
# 2        63.994
# 3        68.040
# 4        72.176
#          ...
# 1699    124.702
# 1700    120.754
# 1701     93.618
# 1702     79.978
# 1703     86.974
# Name: lifeExp, Length: 1704, dtype: float64

# %% [markdown]
# 平均値

# %%
df['lifeExp'].mean()
# Out:
# 59.474439366197174

# %% [markdown]
# 中央値

# %%
df['lifeExp'].median()
# Out:
# 60.7125

# %%
df['lifeExp'].min()
# Out:
# 23.599

# %%
df['lifeExp'].max()
# Out:
# 82.603

# %% [markdown]
# 標準偏差

# %%
df['lifeExp'].std()
# Out:
# 12.917107415241183

# %% [markdown]
# パーセンタイル
#
# 実数（0.0 ~ 1.0）に対し、q 分位数 (q-quantile) は、分布を q : 1 - q に分割する値である。
# ...
# q/100分位数を、q パーセンタイルという。

# %%
df['lifeExp'].quantile(0.95)
# Out:
# 77.437
