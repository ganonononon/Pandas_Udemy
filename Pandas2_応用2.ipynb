# %% [markdown]
# <a href="https://colab.research.google.com/github/ganonononon/Pandas_Udemy/blob/main/Pandas2_%E5%BF%9C%E7%94%A82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ファイルの読み込み

# %%
file_path = '/content/drive/MyDrive/UdemyPandas/dataset/countries_codes_and_coordinates.csv'
df = pd.read_csv(file_path, sep=',')

# %%
df.head(4)
# Out:
#           Country Alpha-2 code Alpha-3 code Numeric code Latitude (average)  \
# 0     Afghanistan         "AF"        "AFG"          "4"               "33"
# 1         Albania         "AL"        "ALB"          "8"               "41"
# 2         Algeria         "DZ"        "DZA"         "12"               "28"
# 3  American Samoa         "AS"        "ASM"         "16"         "-14.3333"
#
#   Longitude (average)
# 0                "65"
# 1                "20"
# 2                 "3"
# 3              "-170"

# %% [markdown]
# 特定のカラムを読み込む
#
# usecols

# %%
df_ = pd.read_csv(file_path, sep=',', usecols=[0,1])
df_.head(2)
# Out:
#        Country Alpha-2 code
# 0  Afghanistan         "AF"
# 1      Albania         "AL"

# %% [markdown]
# merge

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = px.data.gapminder()

# %%
file_path = '/content/drive/MyDrive/UdemyPandas/dataset/countries_codes_and_coordinates.csv'
country_master_df = pd.read_csv(file_path, sep=',', usecols=[2,4,5])

# %%
country_master_df.head()
# Out:
#   Alpha-3 code Latitude (average) Longitude (average)
# 0        "AFG"               "33"                "65"
# 1        "ALB"               "41"                "20"
# 2        "DZA"               "28"                 "3"
# 3        "ASM"         "-14.3333"              "-170"
# 4        "AND"             "42.5"               "1.6"

# %%
country_master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Alpha-3 code         256 non-null    object
#  1   Latitude (average)   256 non-null    object
#  2   Longitude (average)  256 non-null    object
# dtypes: object(3)
# memory usage: 6.1+ KB

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
for col in country_master_df.columns:
  country_master_df[col] = country_master_df[col].apply(lambda x: x.strip()[1:-1])

# %%
country_master_df
# Out:
#     Alpha-3 code Latitude (average) Longitude (average)
# 0            AFG                 33                  65
# 1            ALB                 41                  20
# 2            DZA                 28                   3
# 3            ASM           -14.3333                -170
# 4            AND               42.5                 1.6
# ..           ...                ...                 ...
# 251          WLF              -13.3              -176.2
# 252          ESH               24.5                 -13
# 253          YEM                 15                  48
# 254          ZMB                -15                  30
# 255          ZWE                -20                  30
#
# [256 rows x 3 columns]

# %%
pd.merge(df, country_master_df.drop_duplicates(),
         left_on='iso_alpha', right_on='Alpha-3 code', how='inner')
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num Alpha-3 code Latitude (average) Longitude (average)
# ...

# %% [markdown]
# concat 縦方向に結合

# %%
df1 = df.iloc[:100, :]
df2 = df.iloc[100:200, :]

# %%
df1
# Out:
#         country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 0   Afghanistan      Asia  1952   28.801   8425333    779.445314       AFG
# 1   Afghanistan      Asia  1957   30.332   9240934    820.853030       AFG
# 2   Afghanistan      Asia  1962   31.997  10267083    853.100710       AFG
# 3   Afghanistan      Asia  1967   34.020  11537966    836.197138       AFG
# 4   Afghanistan      Asia  1972   36.088  13079460    739.981106       AFG
# ..          ...       ...   ...      ...       ...           ...       ...
# 95      Bahrain      Asia  2007   75.635    708573  29796.048340       BHR
# 96   Bangladesh      Asia  1952   37.484  46886859    684.244172       BGD
# 97   Bangladesh      Asia  1957   39.348  51365468    661.637458       BGD
# 98   Bangladesh      Asia  1962   41.216  56839289    686.341554       BGD
# 99   Bangladesh      Asia  1967   43.453  62821884    721.186086       BGD
#
#     iso_num
# 0         4
# 1         4
# 2         4
# 3         4
# ...

# %%
df2
# Out:
#           country continent  year  lifeExp        pop   gdpPercap iso_alpha  \
# 100    Bangladesh      Asia  1972   45.252   70759295  630.233627       BGD
# 101    Bangladesh      Asia  1977   46.923   80428306  659.877232       BGD
# 102    Bangladesh      Asia  1982   50.009   93074406  676.981866       BGD
# 103    Bangladesh      Asia  1987   52.819  103764241  751.979403       BGD
# 104    Bangladesh      Asia  1992   56.018  113704579  837.810164       BGD
# ..            ...       ...   ...      ...        ...         ...       ...
# 195  Burkina Faso    Africa  1967   40.697    5127935  794.826560       BFA
# 196  Burkina Faso    Africa  1972   43.591    5433886  854.735976       BFA
# 197  Burkina Faso    Africa  1977   46.137    5889574  743.387037       BFA
# 198  Burkina Faso    Africa  1982   48.122    6634596  807.198586       BFA
# 199  Burkina Faso    Africa  1987   49.557    7586551  912.063142       BFA
#
#      iso_num
# 100       50
# 101       50
# ...

# %%
concat_df = pd.concat([df1, df2])
concat_df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ..            ...       ...   ...      ...       ...         ...       ...
# 195  Burkina Faso    Africa  1967   40.697   5127935  794.826560       BFA
# 196  Burkina Faso    Africa  1972   43.591   5433886  854.735976       BFA
# 197  Burkina Faso    Africa  1977   46.137   5889574  743.387037       BFA
# 198  Burkina Faso    Africa  1982   48.122   6634596  807.198586       BFA
# 199  Burkina Faso    Africa  1987   49.557   7586551  912.063142       BFA
#
#      iso_num
# 0          4
# 1          4
# 2          4
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
